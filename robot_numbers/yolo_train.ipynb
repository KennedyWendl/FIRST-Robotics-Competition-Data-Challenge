# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # pretrained weights

model.train(
    data="robot_number_grabber/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.19 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14  Python-3.11.9 torch-2.10.0+cpu CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# ...

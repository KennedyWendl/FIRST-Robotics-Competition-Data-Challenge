# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # pretrained weights

model.train(
    data="/work/classtmp/kmwendl/FIRST-Robotics-Competition-Data-Challenge/robot_numbers/robot_number_grabber/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.21 🚀 Python-3.13.5 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100 80GB PCIe, 81152MiB)
# ...

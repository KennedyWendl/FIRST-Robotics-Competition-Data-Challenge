# %%
# This code downloads match videos from YouTube links provided in the CSV file. Change the DOWNLOAD_LIMIT variable to set how many videos you want it to download. If the value is None, it will download all the videos.

import pandas as pd
import os
import yt_dlp
import imageio_ffmpeg

# --- SETTINGS ---
DOWNLOAD_LIMIT = 100  # Set to None to download all videos
# -------------------------------

csv_path = 'frc_2025_matches.csv'
output_dir = 'videos'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

def download_match_videos(csv_file, limit=None):
    ffmpeg_exe = imageio_ffmpeg.get_ffmpeg_exe()
    
    ydl_opts = {
        'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
        'outtmpl': os.path.join(output_dir, '%(title)s.%(ext)s'),
        'ffmpeg_location': ffmpeg_exe,
        'quiet': False,
    }

    df = pd.read_csv(csv_file)
    
    # Apply the download limit if specified
    if limit is not None:
        df = df.head(limit)
        print(f"Limit applied: Downloading the first {limit} videos.")

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        for index, row in df.iterrows():
            url = row['youtube_link']
            if pd.isna(url) or url == "": 
                continue
            
            print(f"[{index+1}/{len(df)}] Downloading: {url}")
            try:
                ydl.download([url])
            except Exception as e:
                print(f"Failed to download {url}: {e}")

if __name__ == "__main__":
    download_match_videos(csv_path, limit=DOWNLOAD_LIMIT)
# Out:
# Limit applied: Downloading the first 100 videos.
# [1/100] Downloading: https://www.youtube.com/watch?v=NSWVoO4ZDEs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NSWVoO4ZDEs
# [youtube] NSWVoO4ZDEs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] NSWVoO4ZDEs: Downloading android vr player API JSON
# [info] NSWVoO4ZDEs: Downloading 1 format(s): 137+140
# [download] Destination: videos/Final 1 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   91.87MiB in 00:00:03 at 26.90MiB/s
# [download] Destination: videos/Final 1 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 17.98MiB/s
# [Merger] Merging formats into "videos/Final 1 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Final 1 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Final 1 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [2/100] Downloading: https://www.youtube.com/watch?v=1FpcfKgS3kw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1FpcfKgS3kw
# [youtube] 1FpcfKgS3kw: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 1FpcfKgS3kw: Downloading android vr player API JSON
# [info] 1FpcfKgS3kw: Downloading 1 format(s): 137+140
# [download] Destination: videos/Final 2 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   84.02MiB in 00:00:03 at 26.28MiB/s
# [download] Destination: videos/Final 2 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 15.09MiB/s
# [Merger] Merging formats into "videos/Final 2 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Final 2 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Final 2 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [3/100] Downloading: https://www.youtube.com/watch?v=mAbsfvQlhaw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mAbsfvQlhaw
# [youtube] mAbsfvQlhaw: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] mAbsfvQlhaw: Downloading android vr player API JSON
# [info] mAbsfvQlhaw: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 1 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   74.75MiB in 00:00:03 at 18.86MiB/s
# [download] Destination: videos/Qualification 1 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 4.93MiB/s
# [Merger] Merging formats into "videos/Qualification 1 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 1 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 1 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [4/100] Downloading: https://www.youtube.com/watch?v=xrkAU-qZY-E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xrkAU-qZY-E
# [youtube] xrkAU-qZY-E: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] xrkAU-qZY-E: Downloading android vr player API JSON
# [info] xrkAU-qZY-E: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 10 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.69MiB in 00:00:02 at 32.16MiB/s
# [download] Destination: videos/Qualification 10 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 13.75MiB/s
# [Merger] Merging formats into "videos/Qualification 10 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 10 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 10 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [5/100] Downloading: https://www.youtube.com/watch?v=ae-lJ4geVPg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ae-lJ4geVPg
# [youtube] ae-lJ4geVPg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] ae-lJ4geVPg: Downloading android vr player API JSON
# [info] ae-lJ4geVPg: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 11 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.76MiB in 00:00:12 at 7.32MiB/s
# [download] Destination: videos/Qualification 11 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 15.28MiB/s
# [Merger] Merging formats into "videos/Qualification 11 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 11 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 11 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [6/100] Downloading: https://www.youtube.com/watch?v=sRH7aAUy5Og
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sRH7aAUy5Og
# [youtube] sRH7aAUy5Og: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] sRH7aAUy5Og: Downloading android vr player API JSON
# [info] sRH7aAUy5Og: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 12 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.11MiB in 00:00:02 at 36.00MiB/s
# [download] Destination: videos/Qualification 12 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 18.88MiB/s
# [Merger] Merging formats into "videos/Qualification 12 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 12 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 12 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [7/100] Downloading: https://www.youtube.com/watch?v=UoCPIGg3_f4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UoCPIGg3_f4
# [youtube] UoCPIGg3_f4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] UoCPIGg3_f4: Downloading android vr player API JSON
# ERROR: [youtube] UoCPIGg3_f4: Video unavailable. This video contains content from SME, who has blocked it in your country on copyright grounds
# Failed to download https://www.youtube.com/watch?v=UoCPIGg3_f4: ERROR: [youtube] UoCPIGg3_f4: Video unavailable. This video contains content from SME, who has blocked it in your country on copyright grounds
# [8/100] Downloading: https://www.youtube.com/watch?v=YFcyYa0XFH8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YFcyYa0XFH8
# [youtube] YFcyYa0XFH8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] YFcyYa0XFH8: Downloading android vr player API JSON
# [info] YFcyYa0XFH8: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 14 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   92.29MiB in 00:00:02 at 31.39MiB/s
# [download] Destination: videos/Qualification 14 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 18.53MiB/s
# [Merger] Merging formats into "videos/Qualification 14 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 14 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 14 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [9/100] Downloading: https://www.youtube.com/watch?v=OY7I9H4PzLI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OY7I9H4PzLI
# [youtube] OY7I9H4PzLI: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] OY7I9H4PzLI: Downloading android vr player API JSON
# [info] OY7I9H4PzLI: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 15 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.49MiB in 00:00:03 at 28.91MiB/s
# [download] Destination: videos/Qualification 15 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 18.15MiB/s
# [Merger] Merging formats into "videos/Qualification 15 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 15 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 15 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [10/100] Downloading: https://www.youtube.com/watch?v=9VK8nHMaMFo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9VK8nHMaMFo
# [youtube] 9VK8nHMaMFo: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 9VK8nHMaMFo: Downloading android vr player API JSON
# [info] 9VK8nHMaMFo: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 16 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   87.33MiB in 00:00:02 at 35.89MiB/s
# [download] Destination: videos/Qualification 16 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 17.35MiB/s
# [Merger] Merging formats into "videos/Qualification 16 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 16 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 16 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [11/100] Downloading: https://www.youtube.com/watch?v=R-_G8UFbIIM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=R-_G8UFbIIM
# [youtube] R-_G8UFbIIM: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] R-_G8UFbIIM: Downloading android vr player API JSON
# [info] R-_G8UFbIIM: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 17 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   81.15MiB in 00:00:02 at 28.11MiB/s
# [download] Destination: videos/Qualification 17 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 18.67MiB/s
# [Merger] Merging formats into "videos/Qualification 17 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 17 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 17 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [12/100] Downloading: https://www.youtube.com/watch?v=fvfTY7Sar8Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fvfTY7Sar8Y
# [youtube] fvfTY7Sar8Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] fvfTY7Sar8Y: Downloading android vr player API JSON
# [info] fvfTY7Sar8Y: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 18 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   95.23MiB in 00:00:02 at 34.13MiB/s
# [download] Destination: videos/Qualification 18 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 19.77MiB/s
# [Merger] Merging formats into "videos/Qualification 18 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 18 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 18 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [13/100] Downloading: https://www.youtube.com/watch?v=doCz1FUqBaU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=doCz1FUqBaU
# [youtube] doCz1FUqBaU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] doCz1FUqBaU: Downloading android vr player API JSON
# [info] doCz1FUqBaU: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 19 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   96.59MiB in 00:00:03 at 24.32MiB/s
# [download] Destination: videos/Qualification 19 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 8.57MiB/s
# [Merger] Merging formats into "videos/Qualification 19 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 19 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 19 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [14/100] Downloading: https://www.youtube.com/watch?v=FMuWTpxC_eA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FMuWTpxC_eA
# [youtube] FMuWTpxC_eA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] FMuWTpxC_eA: Downloading android vr player API JSON
# [info] FMuWTpxC_eA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 2 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.49MiB in 00:00:20 at 4.56MiB/s
# [download] Destination: videos/Qualification 2 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 14.50MiB/s
# [Merger] Merging formats into "videos/Qualification 2 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 2 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 2 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [15/100] Downloading: https://www.youtube.com/watch?v=HE6195z04J8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HE6195z04J8
# [youtube] HE6195z04J8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] HE6195z04J8: Downloading android vr player API JSON
# [info] HE6195z04J8: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 20 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   83.17MiB in 00:00:02 at 29.73MiB/s
# [download] Destination: videos/Qualification 20 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 19.76MiB/s
# [Merger] Merging formats into "videos/Qualification 20 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 20 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 20 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [16/100] Downloading: https://www.youtube.com/watch?v=XllHMW_pD84
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XllHMW_pD84
# [youtube] XllHMW_pD84: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] XllHMW_pD84: Downloading android vr player API JSON
# [info] XllHMW_pD84: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 21 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.47MiB in 00:00:03 at 25.69MiB/s
# [download] Destination: videos/Qualification 21 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 10.99MiB/s
# [Merger] Merging formats into "videos/Qualification 21 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 21 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 21 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [17/100] Downloading: https://www.youtube.com/watch?v=Fm-SOusDgz4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Fm-SOusDgz4
# [youtube] Fm-SOusDgz4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Fm-SOusDgz4: Downloading android vr player API JSON
# [info] Fm-SOusDgz4: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 22 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   85.40MiB in 00:00:03 at 23.92MiB/s
# [download] Destination: videos/Qualification 22 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 16.04MiB/s
# [Merger] Merging formats into "videos/Qualification 22 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 22 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 22 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [18/100] Downloading: https://www.youtube.com/watch?v=AY6chm84n7c
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AY6chm84n7c
# [youtube] AY6chm84n7c: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] AY6chm84n7c: Downloading android vr player API JSON
# [info] AY6chm84n7c: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 23 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   95.33MiB in 00:00:02 at 34.48MiB/s
# [download] Destination: videos/Qualification 23 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 16.62MiB/s
# [Merger] Merging formats into "videos/Qualification 23 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 23 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 23 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [19/100] Downloading: https://www.youtube.com/watch?v=KS3qkF39G3Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KS3qkF39G3Y
# [youtube] KS3qkF39G3Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] KS3qkF39G3Y: Downloading android vr player API JSON
# [info] KS3qkF39G3Y: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 24 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   92.11MiB in 00:00:12 at 7.56MiB/s
# [download] Destination: videos/Qualification 24 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 17.70MiB/s
# [Merger] Merging formats into "videos/Qualification 24 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 24 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 24 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [20/100] Downloading: https://www.youtube.com/watch?v=Fob8nV2v9A0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Fob8nV2v9A0
# [youtube] Fob8nV2v9A0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Fob8nV2v9A0: Downloading android vr player API JSON
# [info] Fob8nV2v9A0: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 25 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   93.84MiB in 00:00:02 at 34.10MiB/s
# [download] Destination: videos/Qualification 25 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 25.25MiB/s
# [Merger] Merging formats into "videos/Qualification 25 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 25 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 25 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [21/100] Downloading: https://www.youtube.com/watch?v=ZhXyHNK2eU0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZhXyHNK2eU0
# [youtube] ZhXyHNK2eU0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] ZhXyHNK2eU0: Downloading android vr player API JSON
# [info] ZhXyHNK2eU0: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 26 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   96.36MiB in 00:00:12 at 7.80MiB/s
# [download] Destination: videos/Qualification 26 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 4.11MiB/s
# [Merger] Merging formats into "videos/Qualification 26 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 26 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 26 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [22/100] Downloading: https://www.youtube.com/watch?v=7_w9osPXr8o
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7_w9osPXr8o
# [youtube] 7_w9osPXr8o: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 7_w9osPXr8o: Downloading android vr player API JSON
# [info] 7_w9osPXr8o: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 27 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.73MiB in 00:00:11 at 8.07MiB/s
# [download] Destination: videos/Qualification 27 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 6.39MiB/s
# [Merger] Merging formats into "videos/Qualification 27 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 27 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 27 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [23/100] Downloading: https://www.youtube.com/watch?v=5xPutHyybKA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5xPutHyybKA
# [youtube] 5xPutHyybKA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 5xPutHyybKA: Downloading android vr player API JSON
# [info] 5xPutHyybKA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 28 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.20MiB in 00:00:03 at 29.30MiB/s
# [download] Destination: videos/Qualification 28 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 17.59MiB/s
# [Merger] Merging formats into "videos/Qualification 28 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 28 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 28 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [24/100] Downloading: https://www.youtube.com/watch?v=WROWtoMWB5g
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WROWtoMWB5g
# [youtube] WROWtoMWB5g: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] WROWtoMWB5g: Downloading android vr player API JSON
# [info] WROWtoMWB5g: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 29 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.46MiB in 00:00:03 at 26.57MiB/s
# [download] Destination: videos/Qualification 29 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 18.78MiB/s
# [Merger] Merging formats into "videos/Qualification 29 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 29 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 29 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [25/100] Downloading: https://www.youtube.com/watch?v=AIvbeD93qx8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AIvbeD93qx8
# [youtube] AIvbeD93qx8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] AIvbeD93qx8: Downloading android vr player API JSON
# [info] AIvbeD93qx8: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 3 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   93.31MiB in 00:00:11 at 8.16MiB/s
# [download] Destination: videos/Qualification 3 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 6.43MiB/s
# [Merger] Merging formats into "videos/Qualification 3 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 3 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 3 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [26/100] Downloading: https://www.youtube.com/watch?v=Bum1FPPxuoU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Bum1FPPxuoU
# [youtube] Bum1FPPxuoU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Bum1FPPxuoU: Downloading android vr player API JSON
# [info] Bum1FPPxuoU: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 30 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   93.85MiB in 00:00:12 at 7.68MiB/s
# [download] Destination: videos/Qualification 30 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 6.98MiB/s
# [Merger] Merging formats into "videos/Qualification 30 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 30 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 30 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [27/100] Downloading: https://www.youtube.com/watch?v=70opNdGFrx0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=70opNdGFrx0
# [youtube] 70opNdGFrx0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 70opNdGFrx0: Downloading android vr player API JSON
# [info] 70opNdGFrx0: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 31 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.75MiB in 00:00:09 at 9.67MiB/s
# [download] Destination: videos/Qualification 31 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 7.68MiB/s
# [Merger] Merging formats into "videos/Qualification 31 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 31 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 31 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [28/100] Downloading: https://www.youtube.com/watch?v=J8aH17vNdUE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J8aH17vNdUE
# [youtube] J8aH17vNdUE: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] J8aH17vNdUE: Downloading android vr player API JSON
# [info] J8aH17vNdUE: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 32 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.79MiB in 00:00:02 at 32.45MiB/s
# [download] Destination: videos/Qualification 32 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:01 at 2.32MiB/s
# [Merger] Merging formats into "videos/Qualification 32 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 32 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 32 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [29/100] Downloading: https://www.youtube.com/watch?v=WZVJVEEnv3o
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WZVJVEEnv3o
# [youtube] WZVJVEEnv3o: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] WZVJVEEnv3o: Downloading android vr player API JSON
# [info] WZVJVEEnv3o: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 33 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   95.67MiB in 00:00:39 at 2.40MiB/s
# [download] Destination: videos/Qualification 33 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 3.88MiB/s
# [Merger] Merging formats into "videos/Qualification 33 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 33 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 33 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [30/100] Downloading: https://www.youtube.com/watch?v=BfOo97mayN8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BfOo97mayN8
# [youtube] BfOo97mayN8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] BfOo97mayN8: Downloading android vr player API JSON
# [info] BfOo97mayN8: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 34 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   92.52MiB in 00:00:03 at 29.97MiB/s
# [download] Destination: videos/Qualification 34 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 18.04MiB/s
# [Merger] Merging formats into "videos/Qualification 34 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 34 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 34 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [31/100] Downloading: https://www.youtube.com/watch?v=5y3GkSmaZ-4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5y3GkSmaZ-4
# [youtube] 5y3GkSmaZ-4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 5y3GkSmaZ-4: Downloading android vr player API JSON
# [info] 5y3GkSmaZ-4: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 35 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.86MiB in 00:00:03 at 30.70MiB/s
# [download] Destination: videos/Qualification 35 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 5.81MiB/s
# [Merger] Merging formats into "videos/Qualification 35 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 35 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 35 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [32/100] Downloading: https://www.youtube.com/watch?v=f3xxWxdch1E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=f3xxWxdch1E
# [youtube] f3xxWxdch1E: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] f3xxWxdch1E: Downloading android vr player API JSON
# [info] f3xxWxdch1E: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 36 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   87.60MiB in 00:00:11 at 7.79MiB/s
# [download] Destination: videos/Qualification 36 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 16.54MiB/s
# [Merger] Merging formats into "videos/Qualification 36 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 36 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 36 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [33/100] Downloading: https://www.youtube.com/watch?v=A4fy_5OH49w
# [youtube] Extracting URL: https://www.youtube.com/watch?v=A4fy_5OH49w
# [youtube] A4fy_5OH49w: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] A4fy_5OH49w: Downloading android vr player API JSON
# [info] A4fy_5OH49w: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 37 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   96.02MiB in 00:00:03 at 27.12MiB/s
# [download] Destination: videos/Qualification 37 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 17.85MiB/s
# [Merger] Merging formats into "videos/Qualification 37 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 37 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 37 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [34/100] Downloading: https://www.youtube.com/watch?v=CsNMnwTObrE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CsNMnwTObrE
# [youtube] CsNMnwTObrE: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] CsNMnwTObrE: Downloading android vr player API JSON
# [info] CsNMnwTObrE: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 38 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   90.26MiB in 00:00:02 at 33.27MiB/s
# [download] Destination: videos/Qualification 38 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 18.52MiB/s
# [Merger] Merging formats into "videos/Qualification 38 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 38 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 38 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [35/100] Downloading: https://www.youtube.com/watch?v=uwfPTIh3c6Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uwfPTIh3c6Y
# [youtube] uwfPTIh3c6Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] uwfPTIh3c6Y: Downloading android vr player API JSON
# [info] uwfPTIh3c6Y: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 39 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   84.68MiB in 00:00:06 at 13.86MiB/s
# [download] Destination: videos/Qualification 39 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 5.79MiB/s
# [Merger] Merging formats into "videos/Qualification 39 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 39 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 39 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [36/100] Downloading: https://www.youtube.com/watch?v=oHpSPg8IbfA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oHpSPg8IbfA
# [youtube] oHpSPg8IbfA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] oHpSPg8IbfA: Downloading android vr player API JSON
# [info] oHpSPg8IbfA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 4 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   87.20MiB in 00:00:02 at 30.06MiB/s
# [download] Destination: videos/Qualification 4 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 5.01MiB/s
# [Merger] Merging formats into "videos/Qualification 4 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 4 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 4 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [37/100] Downloading: https://www.youtube.com/watch?v=vofacV7uGuQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vofacV7uGuQ
# [youtube] vofacV7uGuQ: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] vofacV7uGuQ: Downloading android vr player API JSON
# [info] vofacV7uGuQ: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 40 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   88.47MiB in 00:00:02 at 32.43MiB/s
# [download] Destination: videos/Qualification 40 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 18.61MiB/s
# [Merger] Merging formats into "videos/Qualification 40 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 40 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Qualification 40 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [38/100] Downloading: https://www.youtube.com/watch?v=RQm066qkAbA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RQm066qkAbA
# [youtube] RQm066qkAbA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] RQm066qkAbA: Downloading android vr player API JSON
# [info] RQm066qkAbA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 41 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   86.66MiB in 00:00:10 at 7.92MiB/s
# [download] Destination: videos/Qualification 41 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 6.66MiB/s
# [Merger] Merging formats into "videos/Qualification 41 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 41 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 41 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [39/100] Downloading: https://www.youtube.com/watch?v=-OXjpkKLwek
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-OXjpkKLwek
# [youtube] -OXjpkKLwek: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] -OXjpkKLwek: Downloading android vr player API JSON
# [info] -OXjpkKLwek: Downloading 1 format(s): 137+140
# [download] Destination: videos/Qualification 42 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   86.31MiB in 00:00:11 at 7.70MiB/s
# [download] Destination: videos/Qualification 42 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 6.27MiB/s
# [Merger] Merging formats into "videos/Qualification 42 - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Qualification 42 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Qualification 42 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [40/100] Downloading: https://www.youtube.com/watch?v=BUSpuTeOfh8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BUSpuTeOfh8
# [youtube] BUSpuTeOfh8: Downloading webpage
# ...
# [download] 100% of    2.97MiB in 00:00:00 at 6.42MiB/s
# [Merger] Merging formats into "videos/Match 1 (R1) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 1 (R1) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Match 1 (R1) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [89/100] Downloading: https://www.youtube.com/watch?v=mpj8ohAjucU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mpj8ohAjucU
# [youtube] mpj8ohAjucU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] mpj8ohAjucU: Downloading android vr player API JSON
# [info] mpj8ohAjucU: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 2 (R1) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   96.31MiB in 00:00:16 at 5.76MiB/s
# [download] Destination: videos/Match 2 (R1) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 7.59MiB/s
# [Merger] Merging formats into "videos/Match 2 (R1) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 2 (R1) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Match 2 (R1) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [90/100] Downloading: https://www.youtube.com/watch?v=YXCaubpb-pA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YXCaubpb-pA
# [youtube] YXCaubpb-pA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] YXCaubpb-pA: Downloading android vr player API JSON
# [info] YXCaubpb-pA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 3 (R1) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   94.84MiB in 00:00:14 at 6.60MiB/s
# [download] Destination: videos/Match 3 (R1) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 5.17MiB/s
# [Merger] Merging formats into "videos/Match 3 (R1) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 3 (R1) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Match 3 (R1) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [91/100] Downloading: https://www.youtube.com/watch?v=0mnW-WjjzOI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0mnW-WjjzOI
# [youtube] 0mnW-WjjzOI: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 0mnW-WjjzOI: Downloading android vr player API JSON
# [info] 0mnW-WjjzOI: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 4 (R1) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   95.33MiB in 00:00:12 at 7.94MiB/s
# [download] Destination: videos/Match 4 (R1) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 5.43MiB/s
# [Merger] Merging formats into "videos/Match 4 (R1) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 4 (R1) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Match 4 (R1) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [92/100] Downloading: https://www.youtube.com/watch?v=Ll1FJS2uX2k
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ll1FJS2uX2k
# [youtube] Ll1FJS2uX2k: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Ll1FJS2uX2k: Downloading android vr player API JSON
# [info] Ll1FJS2uX2k: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 5 (R2) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   96.48MiB in 00:00:03 at 28.63MiB/s
# [download] Destination: videos/Match 5 (R2) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 20.11MiB/s
# [Merger] Merging formats into "videos/Match 5 (R2) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 5 (R2) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Match 5 (R2) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [93/100] Downloading: https://www.youtube.com/watch?v=lZq5hrDbD9A
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lZq5hrDbD9A
# [youtube] lZq5hrDbD9A: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] lZq5hrDbD9A: Downloading android vr player API JSON
# [info] lZq5hrDbD9A: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 6 (R2) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   81.74MiB in 00:00:12 at 6.79MiB/s
# [download] Destination: videos/Match 6 (R2) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 6.31MiB/s
# [Merger] Merging formats into "videos/Match 6 (R2) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 6 (R2) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# Deleting original file videos/Match 6 (R2) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# [94/100] Downloading: https://www.youtube.com/watch?v=DT52u2Q0LGM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DT52u2Q0LGM
# [youtube] DT52u2Q0LGM: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] DT52u2Q0LGM: Downloading android vr player API JSON
# [info] DT52u2Q0LGM: Downloading 1 format(s): 137+140
# [download] Destination: videos/Match 7 (R2) - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   93.71MiB in 00:00:10 at 8.97MiB/s
# [download] Destination: videos/Match 7 (R2) - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 8.10MiB/s
# [Merger] Merging formats into "videos/Match 7 (R2) - 2025 Rocket City Regional.mp4"
# Deleting original file videos/Match 7 (R2) - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file videos/Match 7 (R2) - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
# [95/100] Downloading: https://www.youtube.com/watch?v=jwDdgbh4uNo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jwDdgbh4uNo
# [youtube] jwDdgbh4uNo: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] jwDdgbh4uNo: Downloading android vr player API JSON
# ERROR: [youtube] jwDdgbh4uNo: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Failed to download https://www.youtube.com/watch?v=jwDdgbh4uNo: ERROR: [youtube] jwDdgbh4uNo: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [96/100] Downloading: https://www.youtube.com/watch?v=sLeY4VAcymc
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sLeY4VAcymc
# [youtube] sLeY4VAcymc: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] sLeY4VAcymc: Downloading android vr player API JSON
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] sLeY4VAcymc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Failed to download https://www.youtube.com/watch?v=sLeY4VAcymc: ERROR: [youtube] sLeY4VAcymc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [97/100] Downloading: https://www.youtube.com/watch?v=q9D6zzas76g
# [youtube] Extracting URL: https://www.youtube.com/watch?v=q9D6zzas76g
# [youtube] q9D6zzas76g: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] q9D6zzas76g: Downloading android vr player API JSON
# ERROR: [youtube] q9D6zzas76g: Video unavailable
# Failed to download https://www.youtube.com/watch?v=q9D6zzas76g: ERROR: [youtube] q9D6zzas76g: Video unavailable
# [98/100] Downloading: https://www.youtube.com/watch?v=k2uCcFpLUJ4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=k2uCcFpLUJ4
# [youtube] k2uCcFpLUJ4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] k2uCcFpLUJ4: Downloading android vr player API JSON
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] k2uCcFpLUJ4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Failed to download https://www.youtube.com/watch?v=k2uCcFpLUJ4: ERROR: [youtube] k2uCcFpLUJ4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [99/100] Downloading: https://www.youtube.com/watch?v=JUyl1bSHoZg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JUyl1bSHoZg
# [youtube] JUyl1bSHoZg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] JUyl1bSHoZg: Downloading android vr player API JSON
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] JUyl1bSHoZg: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Failed to download https://www.youtube.com/watch?v=JUyl1bSHoZg: ERROR: [youtube] JUyl1bSHoZg: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [100/100] Downloading: https://www.youtube.com/watch?v=FJDMw8vU3ks
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FJDMw8vU3ks
# [youtube] FJDMw8vU3ks: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] FJDMw8vU3ks: Downloading android vr player API JSON
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] FJDMw8vU3ks: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Failed to download https://www.youtube.com/watch?v=FJDMw8vU3ks: ERROR: [youtube] FJDMw8vU3ks: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies

# %%
# This code instead downloads one video per event. Modify the UNIQUE_EVENT_LIMIT variable to increase the number of videos downloaded.

import pandas as pd
import os
import yt_dlp
import imageio_ffmpeg

# --- SETTINGS ---
UNIQUE_EVENT_LIMIT = 25   # Number of unique events (1 video per event)
# -----------------

csv_path = 'frc_2025_matches.csv'
output_dir = 'unique_event_videos'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

def download_match_videos(csv_file, unique_event_limit=None):
    ffmpeg_exe = imageio_ffmpeg.get_ffmpeg_exe()
    
    ydl_opts = {
        'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
        'outtmpl': os.path.join(output_dir, '%(title)s.%(ext)s'),
        'ffmpeg_location': ffmpeg_exe,
        'quiet': False,
    }

    df = pd.read_csv(csv_file)

    # Remove rows without valid YouTube links
    df = df[df['youtube_link'].notna() & (df['youtube_link'] != "")]

    # Get first N unique events (in order of appearance)
    unique_events = df['event_name'].dropna().unique()

    if unique_event_limit is not None:
        unique_events = unique_events[:unique_event_limit]
        print(f"Downloading 1 video from each of the first {unique_event_limit} unique events.")

    # Select one row per event
    selected_rows = []
    for event in unique_events:
        event_rows = df[df['event_name'] == event]
        if not event_rows.empty:
            selected_rows.append(event_rows.iloc[0])  # take first match from event

    selected_df = pd.DataFrame(selected_rows)

    print(f"Total videos to download: {len(selected_df)}")

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        for i, row in selected_df.iterrows():
            url = row['youtube_link']
            event = row['event_name']

            print(f"\nDownloading from event: {event}")
            print(f"URL: {url}")

            try:
                ydl.download([url])
            except Exception as e:
                print(f"Failed to download {url}: {e}")

if __name__ == "__main__":
    download_match_videos(csv_path, unique_event_limit=UNIQUE_EVENT_LIMIT)
# Out:
# Downloading 1 video from each of the first 25 unique events.
# Total videos to download: 25
#
# Downloading from event: Rocket City Regional
# URL: https://www.youtube.com/watch?v=NSWVoO4ZDEs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NSWVoO4ZDEs
# [youtube] NSWVoO4ZDEs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] NSWVoO4ZDEs: Downloading android vr player API JSON
# [info] NSWVoO4ZDEs: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Rocket City Regional.f137.mp4
# [download] 100% of   91.87MiB in 00:00:04 at 20.72MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Rocket City Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 11.04MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Rocket City Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Rocket City Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Rocket City Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Archimedes Division
# URL: https://www.youtube.com/watch?v=q9D6zzas76g
# [youtube] Extracting URL: https://www.youtube.com/watch?v=q9D6zzas76g
# [youtube] q9D6zzas76g: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] q9D6zzas76g: Downloading android vr player API JSON
# ERROR: [youtube] q9D6zzas76g: Video unavailable
# Failed to download https://www.youtube.com/watch?v=q9D6zzas76g: ERROR: [youtube] q9D6zzas76g: Video unavailable
#
# Downloading from event: Arkansas Regional
# URL: https://www.youtube.com/watch?v=-H-NZNEp-_0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-H-NZNEp-_0
# [youtube] -H-NZNEp-_0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] -H-NZNEp-_0: Downloading android vr player API JSON
# [info] -H-NZNEp-_0: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Arkansas Regional.f137.mp4
# [download] 100% of   92.75MiB in 00:00:03 at 23.88MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Arkansas Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 6.52MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Arkansas Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Arkansas Regional.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Arkansas Regional.f137.mp4 (pass -k to keep)
#
# Downloading from event: Ozark Mountain Brawl
# URL: https://www.youtube.com/watch?v=bBqTX_orwBk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bBqTX_orwBk
# [youtube] bBqTX_orwBk: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] bBqTX_orwBk: Downloading android vr player API JSON
# ERROR: [youtube] bBqTX_orwBk: This video is not available
# Failed to download https://www.youtube.com/watch?v=bBqTX_orwBk: ERROR: [youtube] bBqTX_orwBk: This video is not available
#
# Downloading from event: Southern Cross Regional
# URL: https://www.youtube.com/watch?v=l26ZX1eArdY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l26ZX1eArdY
# [youtube] l26ZX1eArdY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] l26ZX1eArdY: Downloading android vr player API JSON
# [info] l26ZX1eArdY: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Southern Cross Regional.f137.mp4
# [download] 100% of   79.06MiB in 00:00:03 at 22.92MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Southern Cross Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:00 at 6.41MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Southern Cross Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Southern Cross Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Southern Cross Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Arizona North Regional
# URL: https://www.youtube.com/watch?v=_8BTzR_a5MM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_8BTzR_a5MM
# [youtube] _8BTzR_a5MM: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] _8BTzR_a5MM: Downloading android vr player API JSON
# [info] _8BTzR_a5MM: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Arizona North Regional.f137.mp4
# [download] 100% of   91.84MiB in 00:00:03 at 29.36MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Arizona North Regional.f140.m4a
# [download] 100% of    2.97MiB in 00:00:00 at 6.68MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Arizona North Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Arizona North Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Arizona North Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Arizona East Regional
# URL: https://www.youtube.com/watch?v=odSILlBhX5I
# [youtube] Extracting URL: https://www.youtube.com/watch?v=odSILlBhX5I
# [youtube] odSILlBhX5I: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] odSILlBhX5I: Downloading android vr player API JSON
# [info] odSILlBhX5I: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Arizona East Regional.f137.mp4
# [download] 100% of   94.39MiB in 00:00:06 at 14.38MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Arizona East Regional.f140.m4a
# [download] 100% of    2.92MiB in 00:00:00 at 4.60MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Arizona East Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Arizona East Regional.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Arizona East Regional.f137.mp4 (pass -k to keep)
#
# Downloading from event: Arizona Robotics League Qualifier 1
# URL: https://www.youtube.com/watch?v=YitGdLsJ0d0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YitGdLsJ0d0
# [youtube] YitGdLsJ0d0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] YitGdLsJ0d0: Downloading android vr player API JSON
# [info] YitGdLsJ0d0: Downloading 1 format(s): 299+140
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #1 ｜ Finals Match 1.f299.mp4
# [download] 100% of   82.79MiB in 00:00:07 at 10.88MiB/s
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #1 ｜ Finals Match 1.f140.m4a
# [download] 100% of    3.17MiB in 00:00:00 at 4.47MiB/s
# [Merger] Merging formats into "unique_event_videos/Arizona Robotics League 2025 Qualifier #1 ｜ Finals Match 1.mp4"
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #1 ｜ Finals Match 1.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #1 ｜ Finals Match 1.f299.mp4 (pass -k to keep)
#
# Downloading from event: Arizona Robotics League Qualifier 2
# URL: https://www.youtube.com/watch?v=fE5EpAdCCgw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fE5EpAdCCgw
# [youtube] fE5EpAdCCgw: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] fE5EpAdCCgw: Downloading android vr player API JSON
# [info] fE5EpAdCCgw: Downloading 1 format(s): 299+140
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #2 ｜ Finals Match #1.f299.mp4
# [download] 100% of  115.59MiB in 00:00:09 at 11.81MiB/s
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #2 ｜ Finals Match #1.f140.m4a
# [download] 100% of    3.59MiB in 00:00:01 at 2.97MiB/s
# [Merger] Merging formats into "unique_event_videos/Arizona Robotics League 2025 Qualifier #2 ｜ Finals Match #1.mp4"
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #2 ｜ Finals Match #1.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #2 ｜ Finals Match #1.f299.mp4 (pass -k to keep)
#
# Downloading from event: Arizona Robotics League Qualifier 3
# URL: https://www.youtube.com/watch?v=ngrwq7agtXY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ngrwq7agtXY
# [youtube] ngrwq7agtXY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] ngrwq7agtXY: Downloading android vr player API JSON
# [info] ngrwq7agtXY: Downloading 1 format(s): 299+140
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #3 ｜ Finals Match #1.f299.mp4
# [download] 100% of  104.84MiB in 00:00:06 at 15.11MiB/s
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #3 ｜ Finals Match #1.f140.m4a
# [download] 100% of    3.15MiB in 00:00:00 at 6.01MiB/s
# [Merger] Merging formats into "unique_event_videos/Arizona Robotics League 2025 Qualifier #3 ｜ Finals Match #1.mp4"
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #3 ｜ Finals Match #1.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #3 ｜ Finals Match #1.f299.mp4 (pass -k to keep)
#
# Downloading from event: Arizona Robotics League Qualifier 4
# URL: https://www.youtube.com/watch?v=npaMHxZiJR4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=npaMHxZiJR4
# [youtube] npaMHxZiJR4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] npaMHxZiJR4: Downloading android vr player API JSON
# [info] npaMHxZiJR4: Downloading 1 format(s): 299+140
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #4 ｜ Finals Match #1.f299.mp4
# [download] 100% of   86.38MiB in 00:00:05 at 15.97MiB/s
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #4 ｜ Finals Match #1.f140.m4a
# [download] 100% of    3.30MiB in 00:00:00 at 4.26MiB/s
# [Merger] Merging formats into "unique_event_videos/Arizona Robotics League 2025 Qualifier #4 ｜ Finals Match #1.mp4"
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #4 ｜ Finals Match #1.f299.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #4 ｜ Finals Match #1.f140.m4a (pass -k to keep)
#
# Downloading from event: Arizona Robotics League Qualifier 5
# URL: https://www.youtube.com/watch?v=1m3LaObdGJA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1m3LaObdGJA
# [youtube] 1m3LaObdGJA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 1m3LaObdGJA: Downloading android vr player API JSON
# [info] 1m3LaObdGJA: Downloading 1 format(s): 299+140
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #5 ｜ Finals Match #1.f299.mp4
# [download] 100% of   90.37MiB in 00:00:04 at 20.01MiB/s
# [download] Destination: unique_event_videos/Arizona Robotics League 2025 Qualifier #5 ｜ Finals Match #1.f140.m4a
# [download] 100% of    3.30MiB in 00:00:00 at 5.26MiB/s
# [Merger] Merging formats into "unique_event_videos/Arizona Robotics League 2025 Qualifier #5 ｜ Finals Match #1.mp4"
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #5 ｜ Finals Match #1.f299.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Arizona Robotics League 2025 Qualifier #5 ｜ Finals Match #1.f140.m4a (pass -k to keep)
#
# Downloading from event: BattleCry at WPI
# URL: https://www.youtube.com/watch?v=lcGiblbAXfc
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lcGiblbAXfc
# [youtube] lcGiblbAXfc: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] lcGiblbAXfc: Downloading android vr player API JSON
# [info] lcGiblbAXfc: Downloading 1 format(s): 136+140
# [download] Destination: unique_event_videos/Pulse-View Battlecry25 ｜ Finals Match 1 of 1.f136.mp4
# [download] 100% of   40.83MiB in 00:00:02 at 14.87MiB/s
# [download] Destination: unique_event_videos/Pulse-View Battlecry25 ｜ Finals Match 1 of 1.f140.m4a
# [download] 100% of    2.50MiB in 00:00:00 at 6.15MiB/s
# [Merger] Merging formats into "unique_event_videos/Pulse-View Battlecry25 ｜ Finals Match 1 of 1.mp4"
# Deleting original file unique_event_videos/Pulse-View Battlecry25 ｜ Finals Match 1 of 1.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Pulse-View Battlecry25 ｜ Finals Match 1 of 1.f136.mp4 (pass -k to keep)
#
# Downloading from event: Canadian Pacific Regional
# URL: https://www.youtube.com/watch?v=gzBWsfbPZ3c
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gzBWsfbPZ3c
# [youtube] gzBWsfbPZ3c: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] gzBWsfbPZ3c: Downloading android vr player API JSON
# [info] gzBWsfbPZ3c: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Canadian Pacific Regional.f137.mp4
# [download] 100% of   92.71MiB in 00:00:05 at 17.46MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Canadian Pacific Regional.f140.m4a
# [download] 100% of    2.92MiB in 00:00:00 at 7.72MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Canadian Pacific Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Canadian Pacific Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Canadian Pacific Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Regional Brazil - Brasilia
# URL: https://www.youtube.com/watch?v=EKVjwITxP-I
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EKVjwITxP-I
# [youtube] EKVjwITxP-I: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] EKVjwITxP-I: Downloading android vr player API JSON
# [info] EKVjwITxP-I: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Regional Brazil - Brasilia.f137.mp4
# [download] 100% of   62.22MiB in 00:00:05 at 10.71MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Regional Brazil - Brasilia.f140.m4a
# [download] 100% of    3.05MiB in 00:00:00 at 4.79MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Regional Brazil - Brasilia.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Regional Brazil - Brasilia.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Regional Brazil - Brasilia.f140.m4a (pass -k to keep)
#
# Downloading from event: Regional Brazil - São Paulo
# URL: https://www.youtube.com/watch?v=junXRpWB7ro
# [youtube] Extracting URL: https://www.youtube.com/watch?v=junXRpWB7ro
# [youtube] junXRpWB7ro: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] junXRpWB7ro: Downloading android vr player API JSON
# [info] junXRpWB7ro: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Regional Brazil - Sao Paulo.f137.mp4
# [download] 100% of   85.92MiB in 00:00:05 at 15.19MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Regional Brazil - Sao Paulo.f140.m4a
# [download] 100% of    2.92MiB in 00:00:00 at 5.25MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Regional Brazil - Sao Paulo.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Regional Brazil - Sao Paulo.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Regional Brazil - Sao Paulo.f140.m4a (pass -k to keep)
#
# Downloading from event: Aerospace Valley Regional
# URL: https://www.youtube.com/watch?v=5dhgEttE2Rk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5dhgEttE2Rk
# [youtube] 5dhgEttE2Rk: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 5dhgEttE2Rk: Downloading android vr player API JSON
# [info] 5dhgEttE2Rk: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Aerospace Valley Regional.f137.mp4
# [download] 100% of   91.50MiB in 00:00:04 at 20.16MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Aerospace Valley Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 4.69MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Aerospace Valley Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Aerospace Valley Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Aerospace Valley Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: East Bay Regional
# URL: https://www.youtube.com/watch?v=rC6xTPwthSg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rC6xTPwthSg
# [youtube] rC6xTPwthSg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] rC6xTPwthSg: Downloading android vr player API JSON
# [info] rC6xTPwthSg: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 East Bay Regional.f137.mp4
# [download] 100% of   95.59MiB in 00:00:05 at 16.37MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 East Bay Regional.f140.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 7.25MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 East Bay Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 East Bay Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 East Bay Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Capital City Classic
# URL: https://www.youtube.com/watch?v=fy1-00z8TJE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fy1-00z8TJE
# [youtube] fy1-00z8TJE: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] fy1-00z8TJE: Downloading android vr player API JSON
# ERROR: [youtube] fy1-00z8TJE: This video is not available
# Failed to download https://www.youtube.com/watch?v=fy1-00z8TJE: ERROR: [youtube] fy1-00z8TJE: This video is not available
#
# Downloading from event: CalGames
# URL: https://www.youtube.com/watch?v=YinyUH3Se4g
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YinyUH3Se4g
# [youtube] YinyUH3Se4g: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] YinyUH3Se4g: Downloading android vr player API JSON
# ERROR: [youtube] YinyUH3Se4g: This video is not available
# Failed to download https://www.youtube.com/watch?v=YinyUH3Se4g: ERROR: [youtube] YinyUH3Se4g: This video is not available
#
# Downloading from event: Sacramento Regional
# URL: https://www.youtube.com/watch?v=m1Od903VYQQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=m1Od903VYQQ
# [youtube] m1Od903VYQQ: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] m1Od903VYQQ: Downloading android vr player API JSON
# [info] m1Od903VYQQ: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Sacramento Regional.f137.mp4
# [download] 100% of   94.78MiB in 00:00:06 at 13.55MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Sacramento Regional.f140.m4a
# [download] 100% of    2.96MiB in 00:00:00 at 5.33MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Sacramento Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Sacramento Regional.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Sacramento Regional.f137.mp4 (pass -k to keep)
#
# Downloading from event: Central Valley Regional
# URL: https://www.youtube.com/watch?v=UO7TcoJjyBY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UO7TcoJjyBY
# [youtube] UO7TcoJjyBY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] UO7TcoJjyBY: Downloading android vr player API JSON
# [info] UO7TcoJjyBY: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Central Valley Regional.f137.mp4
# [download] 100% of   82.24MiB in 00:00:04 at 16.48MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Central Valley Regional.f140.m4a
# [download] 100% of    2.95MiB in 00:00:01 at 2.45MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Central Valley Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Central Valley Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Central Valley Regional.f140.m4a (pass -k to keep)
#
# Downloading from event: Los Angeles Regional
# URL: https://www.youtube.com/watch?v=YPLqud_2ERA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YPLqud_2ERA
# [youtube] YPLqud_2ERA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] YPLqud_2ERA: Downloading android vr player API JSON
# [info] YPLqud_2ERA: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Los Angeles Regional.f137.mp4
# [download] 100% of   70.71MiB in 00:00:03 at 19.31MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Los Angeles Regional.f140.m4a
# [download] 100% of    2.91MiB in 00:00:00 at 5.99MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Los Angeles Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Los Angeles Regional.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Los Angeles Regional.f137.mp4 (pass -k to keep)
#
# Downloading from event: Pinnacles Regional
# URL: https://www.youtube.com/watch?v=x4o4szP4GUA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x4o4szP4GUA
# [youtube] x4o4szP4GUA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] x4o4szP4GUA: Downloading android vr player API JSON
# [info] x4o4szP4GUA: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Pinnacles Regional.f137.mp4
# [download] 100% of   97.93MiB in 00:00:05 at 19.45MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Pinnacles Regional.f140.m4a
# [download] 100% of    2.91MiB in 00:00:00 at 3.92MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Pinnacles Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Pinnacles Regional.f140.m4a (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Pinnacles Regional.f137.mp4 (pass -k to keep)
#
# Downloading from event: Orange County Regional
# URL: https://www.youtube.com/watch?v=Xqqco54CAdI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Xqqco54CAdI
# [youtube] Xqqco54CAdI: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Xqqco54CAdI: Downloading android vr player API JSON
# [info] Xqqco54CAdI: Downloading 1 format(s): 137+140
# [download] Destination: unique_event_videos/Final 1 - 2025 Orange County Regional.f137.mp4
# [download] 100% of   86.30MiB in 00:00:04 at 19.90MiB/s
# [download] Destination: unique_event_videos/Final 1 - 2025 Orange County Regional.f140.m4a
# [download] 100% of    2.94MiB in 00:00:00 at 7.25MiB/s
# [Merger] Merging formats into "unique_event_videos/Final 1 - 2025 Orange County Regional.mp4"
# Deleting original file unique_event_videos/Final 1 - 2025 Orange County Regional.f137.mp4 (pass -k to keep)
# Deleting original file unique_event_videos/Final 1 - 2025 Orange County Regional.f140.m4a (pass -k to keep)

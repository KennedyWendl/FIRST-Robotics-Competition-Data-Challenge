# %%
import os
import subprocess
import imageio_ffmpeg

# --- SETTINGS ---
BASE_DIR = os.getcwd()
VIDEO_DIR = os.path.join(BASE_DIR, "videos")
OUTPUT_DIR = os.path.join(BASE_DIR, "training_frames")

START_TIME = 8        # seconds
END_TIME = 160        # 2:40
INTERVAL = 5          # seconds
MAX_VIDEOS = None     # None = all videos, or set to int (e.g., 5)

# --- SETUP ---
os.makedirs(OUTPUT_DIR, exist_ok=True)

video_files = sorted(
    f for f in os.listdir(VIDEO_DIR)
    if f.lower().endswith(".mp4")
)

if MAX_VIDEOS is not None:
    video_files = video_files[:MAX_VIDEOS]

ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()

print(f"Processing {len(video_files)} video(s)...")

# --- PROCESS VIDEOS ---
for idx, video_file in enumerate(video_files):
    video_path = os.path.join(VIDEO_DIR, video_file)
    base_name = os.path.splitext(video_file)[0]

    print(f"\n[{idx+1}] Processing {video_file}")

    current_time = START_TIME

    while current_time <= END_TIME:
        output_filename = f"{base_name}_t{int(current_time)}s.png"
        output_path = os.path.join(OUTPUT_DIR, output_filename)

        cmd = [
            ffmpeg_path,
            "-ss", str(current_time),      # seek to timestamp
            "-i", video_path,
            "-frames:v", "1",              # extract one frame
            "-vsync", "vfr",
            "-q:v", "1",                   # highest quality (for safety)
            "-y",                          # overwrite if exists
            output_path
        ]

        subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        print(f"Saved frame at {current_time}s -> {output_filename}")
        current_time += INTERVAL

print("\nDone.")
# Out:
# Processing 93 video(s)...
#
# [1] Processing Final 1 - 2025 Rocket City Regional.mp4
# Saved frame at 8s -> Final 1 - 2025 Rocket City Regional_t8s.png
# Saved frame at 13s -> Final 1 - 2025 Rocket City Regional_t13s.png
# Saved frame at 18s -> Final 1 - 2025 Rocket City Regional_t18s.png
# Saved frame at 23s -> Final 1 - 2025 Rocket City Regional_t23s.png
# Saved frame at 28s -> Final 1 - 2025 Rocket City Regional_t28s.png
# Saved frame at 33s -> Final 1 - 2025 Rocket City Regional_t33s.png
# Saved frame at 38s -> Final 1 - 2025 Rocket City Regional_t38s.png
# Saved frame at 43s -> Final 1 - 2025 Rocket City Regional_t43s.png
# Saved frame at 48s -> Final 1 - 2025 Rocket City Regional_t48s.png
# Saved frame at 53s -> Final 1 - 2025 Rocket City Regional_t53s.png
# Saved frame at 58s -> Final 1 - 2025 Rocket City Regional_t58s.png
# Saved frame at 63s -> Final 1 - 2025 Rocket City Regional_t63s.png
# Saved frame at 68s -> Final 1 - 2025 Rocket City Regional_t68s.png
# Saved frame at 73s -> Final 1 - 2025 Rocket City Regional_t73s.png
# Saved frame at 78s -> Final 1 - 2025 Rocket City Regional_t78s.png
# Saved frame at 83s -> Final 1 - 2025 Rocket City Regional_t83s.png
# Saved frame at 88s -> Final 1 - 2025 Rocket City Regional_t88s.png
# Saved frame at 93s -> Final 1 - 2025 Rocket City Regional_t93s.png
# Saved frame at 98s -> Final 1 - 2025 Rocket City Regional_t98s.png
# Saved frame at 103s -> Final 1 - 2025 Rocket City Regional_t103s.png
# Saved frame at 108s -> Final 1 - 2025 Rocket City Regional_t108s.png
# Saved frame at 113s -> Final 1 - 2025 Rocket City Regional_t113s.png
# Saved frame at 118s -> Final 1 - 2025 Rocket City Regional_t118s.png
# Saved frame at 123s -> Final 1 - 2025 Rocket City Regional_t123s.png
# Saved frame at 128s -> Final 1 - 2025 Rocket City Regional_t128s.png
# Saved frame at 133s -> Final 1 - 2025 Rocket City Regional_t133s.png
# Saved frame at 138s -> Final 1 - 2025 Rocket City Regional_t138s.png
# Saved frame at 143s -> Final 1 - 2025 Rocket City Regional_t143s.png
# Saved frame at 148s -> Final 1 - 2025 Rocket City Regional_t148s.png
# Saved frame at 153s -> Final 1 - 2025 Rocket City Regional_t153s.png
# Saved frame at 158s -> Final 1 - 2025 Rocket City Regional_t158s.png
#
# [2] Processing Final 2 - 2025 Rocket City Regional.mp4
# Saved frame at 8s -> Final 2 - 2025 Rocket City Regional_t8s.png
# Saved frame at 13s -> Final 2 - 2025 Rocket City Regional_t13s.png
# Saved frame at 18s -> Final 2 - 2025 Rocket City Regional_t18s.png
# Saved frame at 23s -> Final 2 - 2025 Rocket City Regional_t23s.png
# Saved frame at 28s -> Final 2 - 2025 Rocket City Regional_t28s.png
# Saved frame at 33s -> Final 2 - 2025 Rocket City Regional_t33s.png
# Saved frame at 38s -> Final 2 - 2025 Rocket City Regional_t38s.png
# Saved frame at 43s -> Final 2 - 2025 Rocket City Regional_t43s.png
# Saved frame at 48s -> Final 2 - 2025 Rocket City Regional_t48s.png
# Saved frame at 53s -> Final 2 - 2025 Rocket City Regional_t53s.png
# Saved frame at 58s -> Final 2 - 2025 Rocket City Regional_t58s.png
# Saved frame at 63s -> Final 2 - 2025 Rocket City Regional_t63s.png
# Saved frame at 68s -> Final 2 - 2025 Rocket City Regional_t68s.png
# Saved frame at 73s -> Final 2 - 2025 Rocket City Regional_t73s.png
# Saved frame at 78s -> Final 2 - 2025 Rocket City Regional_t78s.png
# Saved frame at 83s -> Final 2 - 2025 Rocket City Regional_t83s.png
# Saved frame at 88s -> Final 2 - 2025 Rocket City Regional_t88s.png
# Saved frame at 93s -> Final 2 - 2025 Rocket City Regional_t93s.png
# Saved frame at 98s -> Final 2 - 2025 Rocket City Regional_t98s.png
# Saved frame at 103s -> Final 2 - 2025 Rocket City Regional_t103s.png
# Saved frame at 108s -> Final 2 - 2025 Rocket City Regional_t108s.png
# Saved frame at 113s -> Final 2 - 2025 Rocket City Regional_t113s.png
# Saved frame at 118s -> Final 2 - 2025 Rocket City Regional_t118s.png
# Saved frame at 123s -> Final 2 - 2025 Rocket City Regional_t123s.png
# Saved frame at 128s -> Final 2 - 2025 Rocket City Regional_t128s.png
# Saved frame at 133s -> Final 2 - 2025 Rocket City Regional_t133s.png
# Saved frame at 138s -> Final 2 - 2025 Rocket City Regional_t138s.png
# Saved frame at 143s -> Final 2 - 2025 Rocket City Regional_t143s.png
# Saved frame at 148s -> Final 2 - 2025 Rocket City Regional_t148s.png
# Saved frame at 153s -> Final 2 - 2025 Rocket City Regional_t153s.png
# Saved frame at 158s -> Final 2 - 2025 Rocket City Regional_t158s.png
#
# [3] Processing Match 1 (R1) - 2025 Rocket City Regional.mp4
# Saved frame at 8s -> Match 1 (R1) - 2025 Rocket City Regional_t8s.png
# Saved frame at 13s -> Match 1 (R1) - 2025 Rocket City Regional_t13s.png
# Saved frame at 18s -> Match 1 (R1) - 2025 Rocket City Regional_t18s.png
# Saved frame at 23s -> Match 1 (R1) - 2025 Rocket City Regional_t23s.png
# Saved frame at 28s -> Match 1 (R1) - 2025 Rocket City Regional_t28s.png
# Saved frame at 33s -> Match 1 (R1) - 2025 Rocket City Regional_t33s.png
# Saved frame at 38s -> Match 1 (R1) - 2025 Rocket City Regional_t38s.png
# Saved frame at 43s -> Match 1 (R1) - 2025 Rocket City Regional_t43s.png
# Saved frame at 48s -> Match 1 (R1) - 2025 Rocket City Regional_t48s.png
# Saved frame at 53s -> Match 1 (R1) - 2025 Rocket City Regional_t53s.png
# Saved frame at 58s -> Match 1 (R1) - 2025 Rocket City Regional_t58s.png
# Saved frame at 63s -> Match 1 (R1) - 2025 Rocket City Regional_t63s.png
# Saved frame at 68s -> Match 1 (R1) - 2025 Rocket City Regional_t68s.png
# Saved frame at 73s -> Match 1 (R1) - 2025 Rocket City Regional_t73s.png
# Saved frame at 78s -> Match 1 (R1) - 2025 Rocket City Regional_t78s.png
# Saved frame at 83s -> Match 1 (R1) - 2025 Rocket City Regional_t83s.png
# Saved frame at 88s -> Match 1 (R1) - 2025 Rocket City Regional_t88s.png
# Saved frame at 93s -> Match 1 (R1) - 2025 Rocket City Regional_t93s.png
# Saved frame at 98s -> Match 1 (R1) - 2025 Rocket City Regional_t98s.png
# Saved frame at 103s -> Match 1 (R1) - 2025 Rocket City Regional_t103s.png
# Saved frame at 108s -> Match 1 (R1) - 2025 Rocket City Regional_t108s.png
# Saved frame at 113s -> Match 1 (R1) - 2025 Rocket City Regional_t113s.png
# Saved frame at 118s -> Match 1 (R1) - 2025 Rocket City Regional_t118s.png
# Saved frame at 123s -> Match 1 (R1) - 2025 Rocket City Regional_t123s.png
# Saved frame at 128s -> Match 1 (R1) - 2025 Rocket City Regional_t128s.png
# Saved frame at 133s -> Match 1 (R1) - 2025 Rocket City Regional_t133s.png
# Saved frame at 138s -> Match 1 (R1) - 2025 Rocket City Regional_t138s.png
# Saved frame at 143s -> Match 1 (R1) - 2025 Rocket City Regional_t143s.png
# Saved frame at 148s -> Match 1 (R1) - 2025 Rocket City Regional_t148s.png
# Saved frame at 153s -> Match 1 (R1) - 2025 Rocket City Regional_t153s.png
# Saved frame at 158s -> Match 1 (R1) - 2025 Rocket City Regional_t158s.png
#
# [4] Processing Match 10 (R3) - 2025 Rocket City Regional.mp4
# Saved frame at 8s -> Match 10 (R3) - 2025 Rocket City Regional_t8s.png
# Saved frame at 13s -> Match 10 (R3) - 2025 Rocket City Regional_t13s.png
# Saved frame at 18s -> Match 10 (R3) - 2025 Rocket City Regional_t18s.png
# Saved frame at 23s -> Match 10 (R3) - 2025 Rocket City Regional_t23s.png
# Saved frame at 28s -> Match 10 (R3) - 2025 Rocket City Regional_t28s.png
# Saved frame at 33s -> Match 10 (R3) - 2025 Rocket City Regional_t33s.png
# Saved frame at 38s -> Match 10 (R3) - 2025 Rocket City Regional_t38s.png
# Saved frame at 43s -> Match 10 (R3) - 2025 Rocket City Regional_t43s.png
# Saved frame at 48s -> Match 10 (R3) - 2025 Rocket City Regional_t48s.png
# Saved frame at 53s -> Match 10 (R3) - 2025 Rocket City Regional_t53s.png
# Saved frame at 58s -> Match 10 (R3) - 2025 Rocket City Regional_t58s.png
# Saved frame at 63s -> Match 10 (R3) - 2025 Rocket City Regional_t63s.png
# Saved frame at 68s -> Match 10 (R3) - 2025 Rocket City Regional_t68s.png
# Saved frame at 73s -> Match 10 (R3) - 2025 Rocket City Regional_t73s.png
# Saved frame at 78s -> Match 10 (R3) - 2025 Rocket City Regional_t78s.png
# Saved frame at 83s -> Match 10 (R3) - 2025 Rocket City Regional_t83s.png
# Saved frame at 88s -> Match 10 (R3) - 2025 Rocket City Regional_t88s.png
# Saved frame at 93s -> Match 10 (R3) - 2025 Rocket City Regional_t93s.png
# Saved frame at 98s -> Match 10 (R3) - 2025 Rocket City Regional_t98s.png
# Saved frame at 103s -> Match 10 (R3) - 2025 Rocket City Regional_t103s.png
# Saved frame at 108s -> Match 10 (R3) - 2025 Rocket City Regional_t108s.png
# Saved frame at 113s -> Match 10 (R3) - 2025 Rocket City Regional_t113s.png
# Saved frame at 118s -> Match 10 (R3) - 2025 Rocket City Regional_t118s.png
# Saved frame at 123s -> Match 10 (R3) - 2025 Rocket City Regional_t123s.png
# Saved frame at 128s -> Match 10 (R3) - 2025 Rocket City Regional_t128s.png
# Saved frame at 133s -> Match 10 (R3) - 2025 Rocket City Regional_t133s.png
# Saved frame at 138s -> Match 10 (R3) - 2025 Rocket City Regional_t138s.png
# Saved frame at 143s -> Match 10 (R3) - 2025 Rocket City Regional_t143s.png
# Saved frame at 148s -> Match 10 (R3) - 2025 Rocket City Regional_t148s.png
# Saved frame at 153s -> Match 10 (R3) - 2025 Rocket City Regional_t153s.png
# Saved frame at 158s -> Match 10 (R3) - 2025 Rocket City Regional_t158s.png
#
# [5] Processing Match 11 (R4) - 2025 Rocket City Regional.mp4
# Saved frame at 8s -> Match 11 (R4) - 2025 Rocket City Regional_t8s.png
